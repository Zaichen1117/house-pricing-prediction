# %%
conda install pandas
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/Anacoda
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2023.5.7           |  py310hecd8cb5_0         153 KB
#     pandas-1.5.3               |  py310h3ea8b11_0        11.5 MB
#     ------------------------------------------------------------
#                                            Total:        11.6 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2022.10.11-hecd8cb5_0 --> 2023.01.10-hecd8cb5_0 None
# ...

# %%
conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backports.functools_lru_cache-1.6.4|     pyhd3eb1b0_0           9 KB
#     backports.tempfile-1.0     |     pyhd3eb1b0_1          11 KB
#     cachecontrol-0.12.11       |   py38hecd8cb5_1          38 KB
#     cachecontrol-with-filecache-0.12.11|   py38hecd8cb5_1           6 KB
#     conda-package-handling-2.1.0|   py38hecd8cb5_0         270 KB
#     conda-package-streaming-0.8.0|   py38hecd8cb5_0          29 KB
#     dill-0.3.6                 |   py38hecd8cb5_0         168 KB
# ...

# %%
conda --version
# Out:
# conda 22.9.0
#
# Note: you may need to restart the kernel to use updated packages.
