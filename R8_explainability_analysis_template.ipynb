# %% [markdown]
# ## 8️⃣ Explaineable Artificial Intelligence (XAI)
# **designed by:** [datamover.ai](https://www.datamover.ai)
#
# This part focuses on explaining the output of a given machine learning model via the [**SHAP**](https://shap.readthedocs.io/en/latest/index.html) (**SH**apley **A**dditive ex**P**lanations), which is based on game theory. The framework can provide both a global and local explanation of the model prediction.

# %%
# Load libraries
import os

import numpy as np
import pandas as pd
from IPython.display import display
import shap
from R3_functions import chain_snap
import pickle

# Set random seed
np.random.seed(42)

# print the JS visualization code to the notebook
shap.initjs()

# %% [markdown]
# **1. Load both the train set and the ML model**

# %% [markdown]
# **Note:** You can copy and paste the target and feature list from the markdown file generated in the previous notebook or directly import the md file.

# %% [markdown]
# **2. Feed the model and feature set to the [shap.Explainer](https://shap.readthedocs.io/en/latest/generated/shap.Explainer.html) to be able to generate the plots necessary to explain the model output.**
#
# 🙋‍♀️ if you model is defined inside a [Pipeline](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html), you should provide the processed features, e.g. standardized values and only the model without the other blocks.

# %% [markdown]
# **3. Generate the [beeswarm plot](https://shap.readthedocs.io/en/latest/generated/shap.plots.beeswarm.html#shap.plots.beeswarm) and explain the findings.**

# %% [markdown]
# **4. Generate the [bar plot](https://shap.readthedocs.io/en/latest/generated/shap.plots.bar.html) and explain the findings.**

# %% [markdown]
# **5. Generate the [waterfall plot](https://shap.readthedocs.io/en/latest/example_notebooks/api_examples/plots/waterfall.html) to assess individual prediction and explain the findings.**

# %% [markdown]
# **6. Generate the [dependence scatter plot](https://shap.readthedocs.io/en/latest/generated/shap.plots.scatter.html#shap.plots.scatter) and explain the findings.**

# %% [markdown]
# **7. Generate the [force plot](https://shap.readthedocs.io/en/latest/generated/shap.plots.force.html) and explain the findings.**

# %%
# show force plot on an individual prediction

# %%
# show force plot on the entire dataset

# %% [markdown]
# **8. Generate the [heatmap plot](https://shap.readthedocs.io/en/latest/example_notebooks/api_examples/plots/heatmap.html) and explain the findings.**

# %% [markdown]
# **9. Generate a summary report.**
#
# *Text here*
